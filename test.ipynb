# %%
import numpy as np
from astropy.constants import G,c,M_sun
import os
import sys

print("Current working directory:", os.getcwd())
print("Python path:", sys.path)
os.chdir('/home/homepc/Documents/Codes/Python/cwlensing')
print(os.getcwd())
# Out:
# Current working directory: /home/homepc
# ...

# %%
import utilities

# %%
file = 'outdir/interpolation/result_point.hdf5'
utilities.load_and_interpolate_2D(file,0.4,0.7)
# Out:
# (1.2800157309932074-0.2242860653270539j)

# %%
w = np.linspace(0.001,80,1000)
y = np.array([0.6151020408163265])

F = utilities.grid_interpolate_2D(file,w, y)

# %%
import matplotlib.pyplot as plt

plt.plot(w, np.abs(F))
plt.xscale("log")

# %%
np.linspace(0.01,1,50)[25]
# Out:
# 0.5151020408163265

# %% [markdown]
# Mesh grid interpolator is implemented and used. More finely spaced interpolation is necessary to get accurate amplification factor.
