# %%
import numpy as np
from astropy.constants import G,c,M_sun
import os
import sys

#print("Current working directory:", os.getcwd())
#print("Python path:", sys.path)
#os.chdir('/home/homepc/Documents/Codes/Python/cwlensing')
#print(os.getcwd())

# %%
import pointparallel

w = np.linspace(0.01,100,1000)
y = np.linspace(0.01,1,100)

result = "testpoint.hdf5"
pointparallel.compute_point_lens_grid(w,y,result)

# %%
file = 'test.hdf5'
pmlF = utilities.load_and_interpolate_2D(file,0.4,0.7)

# %%
w1 = np.linspace(0.1,80,100000)
y1 = np.linspace(0.1,1,2)

F = utilities.grid_interpolate_2D(file,w1, y1)

# %%
import matplotlib.pyplot as plt

plt.plot(w1, np.abs(F))
plt.xscale("log")

# %%
np.linspace(0.01,1,50)[25]
# Out:
# 0.5151020408163265

# %% [markdown]
# Mesh grid interpolator is implemented and used. More finely spaced interpolation is necessary to get accurate amplification factor.

# %%
import h5py

with h5py.File("results.h5", "r") as f:
    print("Datasets in file:")
    print(list(f.keys()))
# Out:
# Datasets in file:
# ['results', 'w_values', 'y_values']
